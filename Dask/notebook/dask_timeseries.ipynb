# %%
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning)

# %%
import os
from datetime import datetime
from pathlib import Path

import pandas as pd
import numpy as np

import dask
from dask import dataframe as dd
from dask import array as da

data_path = Path(os.getcwd()).parent/"data"

# %%
parquet_path = data_path/"repartition_wp_w_div.parquet"

read_ddf = dd.read_parquet(parquet_path)
print(f"Division know : {read_ddf.known_divisions}, number of partition : {read_ddf.npartitions}")
# Out:
# Division know : False, number of partition : 55

# %% [markdown]
# ### Create sample data for code testing

# %%
sample_ddf = \
(read_ddf
 .query("User in (0, 1, 2)")
 .groupby("User")
 .apply(lambda x: x.iloc[0:5])
 .reset_index(drop=True)
 .astype({"Year":"string"})
)
# sample_ddf.compute()
sample_ddf.to_parquet(data_path/"sample.parquet", write_index=False)

# %% [markdown]
# **!!IMPORTANT!!** to `order by` have to `sort_values` the dataframe before .groupby()

# %% [markdown]
# `Categorical` datatype will interfere the Aggregation, even not in the .groupby, better cast to `string`

# %%
sample_ddf = dd.read_parquet(data_path/"sample.parquet")[["Year", "dt", "User", "amount"]]
sample_ddf.compute()
# Out:
#    Year                  dt  User  amount
# 0  2007 2007-07-06 23:53:00     2    1.73
# 1  2007 2007-07-06 16:35:00     2   16.42
# 2  2007 2007-07-06 09:40:00     2   44.90
# 3  2007 2007-07-06 04:36:00     2   35.59
# 4  2007 2007-07-05 14:54:00     2  118.64
# 0  2007 2007-03-31 06:02:00     0   33.10
# 1  2007 2007-03-29 09:43:00     0  176.53
# 2  2007 2007-03-29 06:00:00     0  114.56
# 3  2007 2007-03-29 05:45:00     0  117.62
# 4  2007 2007-03-27 16:22:00     0  110.43
# 0  2007 2007-12-14 06:47:00     1   15.26
# 1  2007 2007-12-09 19:49:00     1   62.18
# 2  2007 2007-12-09 06:36:00     1   17.40
# 3  2007 2007-12-07 14:42:00     1   21.52
# 4  2007 2007-12-06 22:18:00     1   80.00

# %% [markdown]
# `.groupby().first()` = First row of each group

# %%
first_of_each_group = (sample_ddf
 .sort_values("dt", ascending = True)
 .groupby(["User"])
 .first()
 )
first_of_each_group.compute()
# Out:
#       Year                  dt  amount
# User
# 0     2007 2007-03-27 16:22:00  110.43
# 2     2007 2007-07-05 14:54:00  118.64
# 1     2007 2007-12-06 22:18:00   80.00

# %%
sample_ddf.query("User == 0").sort_values("dt").compute().head(1)
# Out:
#    Year                  dt  User  amount
# 4  2007 2007-03-27 16:22:00     0  110.43

# %%
sample_ddf.query("User == 1").sort_values("dt").compute().head(1)
# Out:
#    Year                  dt  User  amount
# 4  2007 2007-12-06 22:18:00     1    80.0

# %% [markdown]
# `.groupby().last()` for last row in the group

# %%
(sample_ddf
 .sort_values("dt", ascending = True)
 .groupby(["User"])
 .last()
 ).compute()
# Out:
#       Year                  dt  amount
# User
# 0     2007 2007-03-31 06:02:00   33.10
# 2     2007 2007-07-06 23:53:00    1.73
# 1     2007 2007-12-14 06:47:00   15.26

# %%
sample_ddf.query("User == 0").sort_values("dt").compute().tail(1)
# Out:
#    Year                  dt  User  amount
# 0  2007 2007-03-31 06:02:00     0    33.1

# %% [markdown]
# ## Lead , Lag function
# **IMPORTANT!! sort data first before lag / lead**

# %%
(sample_ddf
 .sort_values(["User", "dt"], ascending=[True, True])
 .assign(lagged_amount = lambda x : x["amount"].shift(1))
 .assign(ledded_amount = lambda x : x["amount"].shift(-1))
).compute()
# Out:
#    Year                  dt  User  amount  lagged_amount  ledded_amount
# 4  2007 2007-03-27 16:22:00     0  110.43            NaN         117.62
# 3  2007 2007-03-29 05:45:00     0  117.62         110.43         114.56
# 2  2007 2007-03-29 06:00:00     0  114.56         117.62         176.53
# 1  2007 2007-03-29 09:43:00     0  176.53         114.56          33.10
# 0  2007 2007-03-31 06:02:00     0   33.10         176.53          80.00
# 4  2007 2007-12-06 22:18:00     1   80.00          33.10          21.52
# 3  2007 2007-12-07 14:42:00     1   21.52          80.00          17.40
# 2  2007 2007-12-09 06:36:00     1   17.40          21.52          62.18
# 1  2007 2007-12-09 19:49:00     1   62.18          17.40          15.26
# 0  2007 2007-12-14 06:47:00     1   15.26          62.18         118.64
# 4  2007 2007-07-05 14:54:00     2  118.64          15.26          35.59
# 3  2007 2007-07-06 04:36:00     2   35.59         118.64          44.90
# 2  2007 2007-07-06 09:40:00     2   44.90          35.59          16.42
# 1  2007 2007-07-06 16:35:00     2   16.42          44.90           1.73
# 0  2007 2007-07-06 23:53:00     2    1.73          16.42            NaN

# %% [markdown]
# ## Lead , Lag with Partition
# Currenly Dask support partly window function with partition.
# **Better use Pandas for this task**

# %%
# Pandas style
pdf = sample_ddf.compute()
(pdf
 .sort_values(["User", "dt"], ascending=True)
 .assign(by_usr_lag_amt = lambda x : x.groupby("User")["amount"].shift(1))
 .assign(by_usr_led_amt = lambda x : x.groupby("User")["amount"].shift(-1))
)
# Out:
#    Year                  dt  User  amount  by_usr_lag_amt  by_usr_led_amt
# 4  2007 2007-03-27 16:22:00     0  110.43             NaN          117.62
# 3  2007 2007-03-29 05:45:00     0  117.62          110.43          114.56
# 2  2007 2007-03-29 06:00:00     0  114.56          117.62          176.53
# 1  2007 2007-03-29 09:43:00     0  176.53          114.56           33.10
# 0  2007 2007-03-31 06:02:00     0   33.10          176.53             NaN
# 4  2007 2007-12-06 22:18:00     1   80.00             NaN           21.52
# 3  2007 2007-12-07 14:42:00     1   21.52           80.00           17.40
# 2  2007 2007-12-09 06:36:00     1   17.40           21.52           62.18
# 1  2007 2007-12-09 19:49:00     1   62.18           17.40           15.26
# 0  2007 2007-12-14 06:47:00     1   15.26           62.18             NaN
# 4  2007 2007-07-05 14:54:00     2  118.64             NaN           35.59
# 3  2007 2007-07-06 04:36:00     2   35.59          118.64           44.90
# 2  2007 2007-07-06 09:40:00     2   44.90           35.59           16.42
# 1  2007 2007-07-06 16:35:00     2   16.42           44.90            1.73
# 0  2007 2007-07-06 23:53:00     2    1.73           16.42             NaN

# %%
# Pandas style, NOT APPLICABLE with Dask Dataframe
(sample_ddf
 .sort_values(["User", "dt"], ascending=True)
 .assign(by_usr_lag_amt = lambda x : x.groupby("User")["amount"].shift(1))
 .assign(by_usr_led_amt = lambda x : x.groupby("User")["amount"].shift(-1))
)#.compute() will error

# %% [markdown]
# **Dask Series**, have SeriesGroupby that could do the partition lag/lead with `.groupby()[].apply(lambda x : x.shift()`
#
# Note, with `.apply()` have to specifiy keyward `meta`=(column name:data type)

# %%
sorted_ddf = sample_ddf.sort_values(["User", "dt"], ascending=True)
lag_amt = sorted_ddf.groupby("User")["amount"].apply(lambda x: x.shift(1), meta=("lag_amt","float"))
lag_series = lag_amt.compute()

# %%
lag_series.reset_index().query("User == 0").head()
# Out:
#    User  level_1  lag_amt
# 5     0        4      NaN
# 6     0        3   110.43
# 7     0        2   117.62
# 8     0        1   114.56
# 9     0        0   176.53

# %%
sorted_ddf.query("User == 0").compute().head()
# Out:
#    Year                  dt  User  amount
# 4  2007 2007-03-27 16:22:00     0  110.43
# 3  2007 2007-03-29 05:45:00     0  117.62
# 2  2007 2007-03-29 06:00:00     0  114.56
# 1  2007 2007-03-29 09:43:00     0  176.53
# 0  2007 2007-03-31 06:02:00     0   33.10

# %%
# Exploring on transform, not Done
(sample_ddf
 .sort_values(["User", "dt"], ascending=True)
 .groupby("User")
 [["amount"]]
 .transform(lambda x : x.shift(1))
).compute().reset_index()
# Out:
#     index  amount
# 0       4     NaN
# 1       3  118.64
# 2       2   35.59
# 3       1   44.90
# 4       0   16.42
# 5       4     NaN
# 6       3  110.43
# 7       2  117.62
# 8       1  114.56
# 9       0  176.53
# 10      4     NaN
# 11      3   80.00
# 12      2   21.52
# 13      1   17.40
# 14      0   62.18

# %% [markdown]
# ## Window Aggregate
# 2 types of windows aggregate
# A) Without Partition
# B) With Partition
#
# with row position parameter like
# - Rows between
# - Unbound precedingm
# - Unbound following

# %%
sample_ddf = dd.read_parquet(data_path/"sample.parquet")[["Year", "dt", "User", "amount"]]
pdf = sample_ddf.compute()

# %%
display(pdf.sort_values(["User", "dt"], ascending=[True, True]))
# Out:
#    Year                  dt  User  amount
# 4  2007 2007-03-27 16:22:00     0  110.43
# 3  2007 2007-03-29 05:45:00     0  117.62
# 2  2007 2007-03-29 06:00:00     0  114.56
# 1  2007 2007-03-29 09:43:00     0  176.53
# 0  2007 2007-03-31 06:02:00     0   33.10
# 4  2007 2007-12-06 22:18:00     1   80.00
# 3  2007 2007-12-07 14:42:00     1   21.52
# 2  2007 2007-12-09 06:36:00     1   17.40
# 1  2007 2007-12-09 19:49:00     1   62.18
# 0  2007 2007-12-14 06:47:00     1   15.26
# 4  2007 2007-07-05 14:54:00     2  118.64
# 3  2007 2007-07-06 04:36:00     2   35.59
# 2  2007 2007-07-06 09:40:00     2   44.90
# 1  2007 2007-07-06 16:35:00     2   16.42
# 0  2007 2007-07-06 23:53:00     2    1.73

# %% [markdown]
# **SQL equivalant**
#
# ```sql
# select *
# , sum(amount) over (order by dt asc
#                     rows between 2 preceding and current row) as rolling3_sum
# from sample_ddf
# ```

# %% [markdown]
# #### Pandas

# %%
# Pandas - result same as SQL
(pdf
 .sort_values(["User", "dt"], ascending=True)
 .assign(rolling3_sum = lambda x : x["amount"].rolling(window=3, min_periods=1).sum().reset_index(drop=True).values)
)
# Out:
#    Year                  dt  User  amount  rolling3_sum
# 4  2007 2007-03-27 16:22:00     0  110.43        110.43
# 3  2007 2007-03-29 05:45:00     0  117.62        228.05
# 2  2007 2007-03-29 06:00:00     0  114.56        342.61
# 1  2007 2007-03-29 09:43:00     0  176.53        408.71
# 0  2007 2007-03-31 06:02:00     0   33.10        324.19
# 4  2007 2007-12-06 22:18:00     1   80.00        289.63
# 3  2007 2007-12-07 14:42:00     1   21.52        134.62
# 2  2007 2007-12-09 06:36:00     1   17.40        118.92
# 1  2007 2007-12-09 19:49:00     1   62.18        101.10
# 0  2007 2007-12-14 06:47:00     1   15.26         94.84
# 4  2007 2007-07-05 14:54:00     2  118.64        196.08
# 3  2007 2007-07-06 04:36:00     2   35.59        169.49
# 2  2007 2007-07-06 09:40:00     2   44.90        199.13
# 1  2007 2007-07-06 16:35:00     2   16.42         96.91
# 0  2007 2007-07-06 23:53:00     2    1.73         63.05

# %%
# Pandas - without out min_period=1, Pandas will give NaN for row with not enough data to calculate windos
(pdf
 .assign(rolling3_sum = lambda x : x["amount"].rolling(window=3).sum().reset_index(drop=True).values)
)
# Out:
#    Year                  dt  User  amount  rolling3_sum
# 0  2007 2007-07-06 23:53:00     2    1.73           NaN
# 1  2007 2007-07-06 16:35:00     2   16.42           NaN
# 2  2007 2007-07-06 09:40:00     2   44.90         63.05
# 3  2007 2007-07-06 04:36:00     2   35.59         96.91
# 4  2007 2007-07-05 14:54:00     2  118.64        199.13
# 0  2007 2007-03-31 06:02:00     0   33.10        187.33
# 1  2007 2007-03-29 09:43:00     0  176.53        328.27
# 2  2007 2007-03-29 06:00:00     0  114.56        324.19
# 3  2007 2007-03-29 05:45:00     0  117.62        408.71
# 4  2007 2007-03-27 16:22:00     0  110.43        342.61
# 0  2007 2007-12-14 06:47:00     1   15.26        243.31
# 1  2007 2007-12-09 19:49:00     1   62.18        187.87
# 2  2007 2007-12-09 06:36:00     1   17.40         94.84
# 3  2007 2007-12-07 14:42:00     1   21.52        101.10
# 4  2007 2007-12-06 22:18:00     1   80.00        118.92

# %% [markdown]
# ### Pandas - time aware window aggregate
# **Pandas need to `set_index(datetime).sort_index()` before this operation

# %% [markdown]
# **SQL equivalant**
# ```sql
# select *
# , sum(amount) over (order by dt asc
#                     range between 3 days preceding and current row) as roll3d_sum
# from sample_ddf
# ```

# %%
pdf.set_index("dt").sort_index()
# Out:
#                      Year  User  amount
# dt
# 2007-03-27 16:22:00  2007     0  110.43
# 2007-03-29 05:45:00  2007     0  117.62
# 2007-03-29 06:00:00  2007     0  114.56
# 2007-03-29 09:43:00  2007     0  176.53
# 2007-03-31 06:02:00  2007     0   33.10
# 2007-07-05 14:54:00  2007     2  118.64
# 2007-07-06 04:36:00  2007     2   35.59
# 2007-07-06 09:40:00  2007     2   44.90
# 2007-07-06 16:35:00  2007     2   16.42
# 2007-07-06 23:53:00  2007     2    1.73
# 2007-12-06 22:18:00  2007     1   80.00
# 2007-12-07 14:42:00  2007     1   21.52
# 2007-12-09 06:36:00  2007     1   17.40
# 2007-12-09 19:49:00  2007     1   62.18
# 2007-12-14 06:47:00  2007     1   15.26

# %%
(pdf
 .set_index("dt").sort_index() # must set index to datetime and sort it
 .assign(roll3d_sum = lambda x : x.rolling("3D")["amount"].sum())
 )
# Out:
#                      Year  User  amount  roll3d_sum
# dt
# 2007-03-27 16:22:00  2007     0  110.43      110.43
# 2007-03-29 05:45:00  2007     0  117.62      228.05
# 2007-03-29 06:00:00  2007     0  114.56      342.61
# 2007-03-29 09:43:00  2007     0  176.53      519.14
# 2007-03-31 06:02:00  2007     0   33.10      441.81
# 2007-07-05 14:54:00  2007     2  118.64      118.64
# 2007-07-06 04:36:00  2007     2   35.59      154.23
# 2007-07-06 09:40:00  2007     2   44.90      199.13
# 2007-07-06 16:35:00  2007     2   16.42      215.55
# 2007-07-06 23:53:00  2007     2    1.73      217.28
# 2007-12-06 22:18:00  2007     1   80.00       80.00
# 2007-12-07 14:42:00  2007     1   21.52      101.52
# 2007-12-09 06:36:00  2007     1   17.40      118.92
# 2007-12-09 19:49:00  2007     1   62.18      181.10
# 2007-12-14 06:47:00  2007     1   15.26       15.26

# %% [markdown]
# ### Dask
# Dask need to `set_index` on datetime datatype (and convert to know division), then could do the rolling operation

# %%
sample_ddf.known_divisions
# Out:
# False

# %%
timed_idx_ddf = sample_ddf.set_index("dt", sort=True)

# %%
timed_idx_ddf.known_divisions
# Out:
# True

# %%
timed_idx_ddf.npartitions
# Out:
# 55

# %%
timed_idx_ddf.divisions[:10]
# Out:
# (Timestamp('2007-03-27 16:22:00'),
#  Timestamp('2007-03-28 02:13:20.181818112'),
#  Timestamp('2007-03-28 12:04:40.363636480'),
#  Timestamp('2007-03-28 21:56:00.545454592'),
#  Timestamp('2007-03-29 05:45:24.545454592'),
#  Timestamp('2007-03-29 05:47:23.181818112'),
#  Timestamp('2007-03-29 05:49:21.818181888'),
#  Timestamp('2007-03-29 05:51:20.454545408'),
#  Timestamp('2007-03-29 05:53:19.090909184'),
#  Timestamp('2007-03-29 05:55:17.727272704'))

# %%
(timed_idx_ddf
#  .sort_values(["User", "dt"], ascending=True)
 .assign(roll3_sum = lambda x : x["amount"].rolling(window = 2, min_periods=1).sum())
).compute()
# Out:
#                      Year  User  amount  roll3_sum
# dt
# 2007-03-27 16:22:00  2007     0  110.43     110.43
# 2007-03-29 05:45:00  2007     0  117.62     228.05
# 2007-03-29 06:00:00  2007     0  114.56     232.18
# 2007-03-29 09:43:00  2007     0  176.53     291.09
# 2007-03-31 06:02:00  2007     0   33.10     209.63
# 2007-07-05 14:54:00  2007     2  118.64     151.74
# 2007-07-06 04:36:00  2007     2   35.59     154.23
# 2007-07-06 09:40:00  2007     2   44.90      80.49
# 2007-07-06 16:35:00  2007     2   16.42      61.32
# 2007-07-06 23:53:00  2007     2    1.73      18.15
# 2007-12-06 22:18:00  2007     1   80.00      81.73
# 2007-12-07 14:42:00  2007     1   21.52     101.52
# 2007-12-09 06:36:00  2007     1   17.40      38.92
# 2007-12-09 19:49:00  2007     1   62.18      79.58
# 2007-12-14 06:47:00  2007     1   15.26      77.44

# %% [markdown]
# Dask partition conflict when increase window size, partition size have to be big (or, npartition small)

# %%
timed_idx_ddf = timed_idx_ddf.repartition(npartitions=1)
(timed_idx_ddf
 .assign(roll3_sum = lambda x : x["amount"].rolling(window = 4, min_periods=1).sum())
).compute()
# Out:
#                      Year  User  amount  roll3_sum
# dt
# 2007-03-27 16:22:00  2007     0  110.43     110.43
# 2007-03-29 05:45:00  2007     0  117.62     228.05
# 2007-03-29 06:00:00  2007     0  114.56     342.61
# 2007-03-29 09:43:00  2007     0  176.53     519.14
# 2007-03-31 06:02:00  2007     0   33.10     441.81
# 2007-07-05 14:54:00  2007     2  118.64     442.83
# 2007-07-06 04:36:00  2007     2   35.59     363.86
# 2007-07-06 09:40:00  2007     2   44.90     232.23
# 2007-07-06 16:35:00  2007     2   16.42     215.55
# 2007-07-06 23:53:00  2007     2    1.73      98.64
# 2007-12-06 22:18:00  2007     1   80.00     143.05
# 2007-12-07 14:42:00  2007     1   21.52     119.67
# 2007-12-09 06:36:00  2007     1   17.40     120.65
# 2007-12-09 19:49:00  2007     1   62.18     181.10
# 2007-12-14 06:47:00  2007     1   15.26     116.36

# %% [markdown]
# ### Dask - time aware window aggregate

# %%
timed_idx_ddf = sample_ddf.set_index("dt", sort=True)

# %%
timed_idx_ddf["roll3d_sum"] = timed_idx_ddf["amount"].rolling("3D").sum()

# %%
timed_idx_ddf.compute()
# Out:
#                      Year  User  amount  roll3d_sum
# dt
# 2007-03-27 16:22:00  2007     0  110.43      110.43
# 2007-03-29 05:45:00  2007     0  117.62      228.05
# 2007-03-29 06:00:00  2007     0  114.56      342.61
# 2007-03-29 09:43:00  2007     0  176.53      519.14
# 2007-03-31 06:02:00  2007     0   33.10      441.81
# 2007-07-05 14:54:00  2007     2  118.64      118.64
# 2007-07-06 04:36:00  2007     2   35.59      154.23
# 2007-07-06 09:40:00  2007     2   44.90      199.13
# 2007-07-06 16:35:00  2007     2   16.42      215.55
# 2007-07-06 23:53:00  2007     2    1.73      217.28
# 2007-12-06 22:18:00  2007     1   80.00       80.00
# 2007-12-07 14:42:00  2007     1   21.52      101.52
# 2007-12-09 06:36:00  2007     1   17.40      118.92
# 2007-12-09 19:49:00  2007     1   62.18      181.10
# 2007-12-14 06:47:00  2007     1   15.26       15.26

# %%
(sample_ddf
 .set_index("dt", sort=True)
 .assign(roll3d_sum = lambda x : x["amount"].rolling("3D").sum())
).compute()
# Out:
#                      Year  User  amount  roll3d_sum
# dt
# 2007-03-27 16:22:00  2007     0  110.43      110.43
# 2007-03-29 05:45:00  2007     0  117.62      228.05
# 2007-03-29 06:00:00  2007     0  114.56      342.61
# 2007-03-29 09:43:00  2007     0  176.53      519.14
# 2007-03-31 06:02:00  2007     0   33.10      441.81
# 2007-07-05 14:54:00  2007     2  118.64      118.64
# 2007-07-06 04:36:00  2007     2   35.59      154.23
# 2007-07-06 09:40:00  2007     2   44.90      199.13
# 2007-07-06 16:35:00  2007     2   16.42      215.55
# 2007-07-06 23:53:00  2007     2    1.73      217.28
# 2007-12-06 22:18:00  2007     1   80.00       80.00
# 2007-12-07 14:42:00  2007     1   21.52      101.52
# 2007-12-09 06:36:00  2007     1   17.40      118.92
# 2007-12-09 19:49:00  2007     1   62.18      181.10
# 2007-12-14 06:47:00  2007     1   15.26       15.26

# %% [markdown]
# ## Windows aggregate With Partition
#
# **SQL equivalant**
#
# ```sql
# select *
# , sum(amount) over (partition by User order by dt asc
#                     rows between 2 preceding and current row) as rolling3_sum
# from sample_ddf
# ```

# %% [markdown]
# ### Pandas

# %%
# Pandas - result same as SQL
(pdf
 .sort_values(["User", "dt"], ascending=True)
 .assign(rolling3_sum_by_usr = lambda x : x.groupby(["User"])["amount"]
                                           .rolling(window=3, min_periods=1).sum()
                                           .reset_index(drop=True).values) # Reset & drop index, convert to numpy and attached back to data frame
)
# Out:
#    Year                  dt  User  amount  rolling3_sum_by_usr
# 4  2007 2007-03-27 16:22:00     0  110.43               110.43
# 3  2007 2007-03-29 05:45:00     0  117.62               228.05
# 2  2007 2007-03-29 06:00:00     0  114.56               342.61
# 1  2007 2007-03-29 09:43:00     0  176.53               408.71
# 0  2007 2007-03-31 06:02:00     0   33.10               324.19
# 4  2007 2007-12-06 22:18:00     1   80.00                80.00
# 3  2007 2007-12-07 14:42:00     1   21.52               101.52
# 2  2007 2007-12-09 06:36:00     1   17.40               118.92
# 1  2007 2007-12-09 19:49:00     1   62.18               101.10
# 0  2007 2007-12-14 06:47:00     1   15.26                94.84
# 4  2007 2007-07-05 14:54:00     2  118.64               118.64
# 3  2007 2007-07-06 04:36:00     2   35.59               154.23
# 2  2007 2007-07-06 09:40:00     2   44.90               199.13
# 1  2007 2007-07-06 16:35:00     2   16.42                96.91
# 0  2007 2007-07-06 23:53:00     2    1.73                63.05

# %% [markdown]
# ### Dask - (Need further explore)
# Could get the result as Dask Array , but could not combine back to original dataframe

# %%
# Dask , must rolling with known division
timed_idx_ddf = sample_ddf.set_index("dt", sort=True).repartition(npartitions=1)
idx = timed_idx_ddf.index

# timed_idx_ddf["rolling3_sum_by_usr"] = \
# arr = timed_idx_ddf.groupby("User")["amount"].rolling(window=3).sum().reset_index()[["amount"]].to_dask_array(lengths=True)
ser = timed_idx_ddf.groupby("User")["amount"].rolling(window=3).sum().reset_index(drop=True)
ser
new = dd.concat([timed_idx_ddf, ser], axis=1)
new.compute()
# arr = timed_idx_ddf.groupby("User")["amount"].rolling(window=3).sum().to_dask_array(lengths=True)
# arr.compute()
# ddf = arr.to_dask_dataframe(columns="rolling2_sum_by_usr", index=idx)
# ddf = arr.to_dask_dataframe()
# ddf.compute()
# arr.compute()
# timed_idx_ddf["olling3_sum_by_usr"] = arr.to_
# ddf = dd.from_array(arr)
# ddf

# arr.visualize()
# timed_idx_ddf["rolling3_sum_by_usr"] = arr.to_dask_array().reshape(-1,1)

# timed_idx_ddf.compute()
# type(arr.reset_index()["amount"])

# timed_idx_ddf["rolling3_sum_by_usr"] = \
# timed_idx_ddf.groupby("User")["amount"].rolling(window=3).sum().reset_index()["amount"]

# timed_idx_ddf.compute()
# arr.compute().shape
# arr.to_dask_dataframe().compute()
# arr_ddf = arr.to_dask_dataframe()
# arr_ddf.compute()
# timed_idx_ddf.compute()
# (timed_idx_ddf
#  .assign(rolling3_sum_by_usr = lambda x : x.groupby(["User"])["amount"].rolling(window=3).sum()
#         #  .reset_index(drop=True).values)
# )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 10
#       8 ser
#       9 new = dd.concat([timed_idx_ddf, ser], axis=1)
# ---> 10 new.compute()
#      11 # arr = timed_idx_ddf.groupby("User")["amount"].rolling(window=3).sum().to_dask_array(lengths=True)
#      12 # arr.compute()
#      13 # ddf = arr.to_dask_dataframe(columns="rolling2_sum_by_usr", index=idx)
#    (...)
#      38 #         #  .reset_index(drop=True).values)
#      39 # )
#
# File ~/miniconda3/envs/dask/lib/python3.12/site-packages/dask_expr/_collection.py:475, in FrameBase.compute(self, fuse, **kwargs)
#     473 if not isinstance(out, Scalar):
#     474     out = out.repartition(npartitions=1)
# --> 475 out = out.optimize(fuse=fuse)
#     476 return DaskMethodsMixin.compute(out, **kwargs)
#
# File ~/miniconda3/envs/dask/lib/python3.12/site-packages/dask_expr/_collection.py:590, in FrameBase.optimize(self, fuse)
#     572 def optimize(self, fuse: bool = True):
#     573     """Optimizes the DataFrame.
#     574
#     575     Runs the optimizer with all steps over the DataFrame and wraps the result in a
#    (...)
#     588         The optimized Dask Dataframe
#     589     """
# --> 590     return new_collection(self.expr.optimize(fuse=fuse))
#
# File ~/miniconda3/envs/dask/lib/python3.12/site-packages/dask_expr/_expr.py:94, in Expr.optimize(self, **kwargs)
#      93 def optimize(self, **kwargs):
# ---> 94     return optimize(self, **kwargs)
#
# File ~/miniconda3/envs/dask/lib/python3.12/site-packages/dask_expr/_expr.py:3028, in optimize(expr, fuse)
#    3007 """High level query optimization
#    3008
#    3009 This leverages three optimization passes:
#    (...)
#    3024 optimize_blockwise_fusion
#    3025 """
#    3026 stage: core.OptimizerStage = "fused" if fuse else "simplified-physical"
# -> 3028 return optimize_until(expr, stage)
#
# File ~/miniconda3/envs/dask/lib/python3.12/site-packages/dask_expr/_expr.py:2989, in optimize_until(expr, stage)
#    2986     return expr
#    2988 # Lower
# -> 2989 expr = expr.lower_completely()
#    2990 if stage == "physical":
#    2991     return expr
#
# File ~/miniconda3/envs/dask/lib/python3.12/site-packages/dask_expr/_core.py:436, in Expr.lower_completely(self)
#     434 expr = self
#     435 while True:
# --> 436     new = expr.lower_once()
#     437     if new._name == expr._name:
#     438         break
#
# File ~/miniconda3/envs/dask/lib/python3.12/site-packages/dask_expr/_core.py:393, in Expr.lower_once(self)
#     390 expr = self
#     392 # Lower this node
# --> 393 out = expr._lower()
#     394 if out is None:
#     395     out = expr
#
# File ~/miniconda3/envs/dask/lib/python3.12/site-packages/dask_expr/_repartition.py:81, in Repartition._lower(self)
#      79     return None
#      80 if self.operand("new_partitions") is not None:
# ---> 81     if self.new_partitions < self.frame.npartitions:
#      82         return RepartitionToFewer(self.frame, self.operand("new_partitions"))
#      83     elif self.new_partitions == self.frame.npartitions:
#      84         # Remove if partitions are equal
#
# File ~/miniconda3/envs/dask/lib/python3.12/site-packages/dask_expr/_expr.py:398, in Expr.npartitions(self)
#     396     return self.operands[idx]
#     397 else:
# --> 398     return len(self.divisions) - 1
#
# File ~/miniconda3/envs/dask/lib/python3.12/functools.py:995, in cached_property.__get__(self, instance, owner)
#     993 val = cache.get(self.attrname, _NOT_FOUND)
#     994 if val is _NOT_FOUND:
# --> 995     val = self.func(instance)
#     996     try:
#     997         cache[self.attrname] = val
#
# File ~/miniconda3/envs/dask/lib/python3.12/site-packages/dask_expr/_expr.py:382, in Expr.divisions(self)
#     380 @functools.cached_property
#     381 def divisions(self):
# --> 382     return tuple(self._divisions())
#
# File ~/miniconda3/envs/dask/lib/python3.12/site-packages/dask_expr/_concat.py:83, in Concat._divisions(self)
#      79     if {df.npartitions for df in self._frames} == {1}:
#      80         divisions = set(
#      81             flatten([e.divisions for e in dfs], container=tuple)
#      82         )
# ---> 83         return min(divisions), max(divisions)
#      84     return dfs[0].divisions
#      85 elif self._all_known_divisions:
#
# TypeError: '<' not supported between instances of 'Timestamp' and 'NoneType'

# %% [markdown]
# SQL equivalant
#
# ```sql
# select *
# , sum(amount) over (partition by User order by dt asc
#                     rows between 2 preceding and current row) as rolling3_sum
# from sample_ddf
# ```

# %% [markdown]
# Time awared rolling at monthly have issue on the cut point of each month end not equal (29, 30, 31)

# %%
sorted_ddf["rolling_mnth_sum"] = sorted_ddf["amount"].rolling("1M").sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[237], line 1
# ----> 1 sorted_ddf["rolling_mnth_sum"] = sorted_ddf["amount"].rolling("1M").sum()
#
# File ~/miniconda3/envs/dask/lib/python3.12/site-packages/dask_expr/_collection.py:963, in FrameBase.rolling(self, window, **kwargs)
#     936 """Provides rolling transformations.
#     937
#     938 Parameters
#    (...)
#     959 a Rolling object on which to call a method to compute a statistic
#     960 """
#     961 from dask_expr._rolling import Rolling
# --> 963 return Rolling(self, window, **kwargs)
#
# File ~/miniconda3/envs/dask/lib/python3.12/site-packages/dask_expr/_rolling.py:256, in Rolling.__init__(self, obj, window, groupby_kwargs, groupby_slice, min_periods, center, win_type)
#     250 if obj.divisions[0] is None and len(obj.divisions) > 2:
#     251     msg = (
#     252         "Can only rolling dataframes with known divisions\n"
#     253         "See https://docs.dask.org/en/latest/dataframe-design.html#partitions\n"
#     254         "for more information."
#     255     )
# --> 256     raise ValueError(msg)
#     257 self.obj = obj
#     258 self.window = window
#
# ValueError: Can only rolling dataframes with known divisions
# See https://docs.dask.org/en/latest/dataframe-design.html#partitions
# for more information.
